# %% [markdown]
# # ANALYSIS OF AIR POLLUTION FROM YEAR 2015 TO 2020

# %% [markdown]
# Air is what keeps humans alive but Pollution is the greatest risk to human life.The present study can be useful in analysis of air pollution and the pollutants that plays main role in creating pollution in environment.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # To read the dataset file using pandas

# %%
df = pd.read_csv("C:\Project\city_day.csv")

# %% [markdown]
# # Gives info of first 10 rows

# %%
df.head(10)
# Out:
#         City        Date  PM2.5  PM10      NO    NO2     NOx  NH3      CO  \
# 0  Ahmedabad  2015-01-01    NaN   NaN    0.92  18.22   17.15  NaN    0.92
# 1  Ahmedabad  2015-01-02    NaN   NaN    0.97  15.69   16.46  NaN    0.97
# 2  Ahmedabad  2015-01-03    NaN   NaN   17.40  19.30   29.70  NaN   17.40
# 3  Ahmedabad  2015-01-04    NaN   NaN    1.70  18.48   17.97  NaN    1.70
# 4  Ahmedabad  2015-01-05    NaN   NaN   22.10  21.42   37.76  NaN   22.10
# 5  Ahmedabad  2015-01-06    NaN   NaN   45.41  38.48   81.50  NaN   45.41
# 6  Ahmedabad  2015-01-07    NaN   NaN  112.16  40.62  130.77  NaN  112.16
# 7  Ahmedabad  2015-01-08    NaN   NaN   80.87  36.74   96.75  NaN   80.87
# 8  Ahmedabad  2015-01-09    NaN   NaN   29.16  31.00   48.00  NaN   29.16
# 9  Ahmedabad  2015-01-10    NaN   NaN     NaN   7.04    0.00  NaN     NaN
#
#      SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  27.64  133.36     0.00     0.02    0.00  NaN        NaN
# ...

# %% [markdown]
# # Gives info of last 10 rows

# %%
df.tail(10)
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 29521  Visakhapatnam  2020-06-22  33.17  108.22  5.58  42.45  27.06  13.70
# 29522  Visakhapatnam  2020-06-23  25.40   83.38  2.76  34.09  19.92  13.13
# 29523  Visakhapatnam  2020-06-24  34.36   90.90  1.22  23.38  13.12  14.45
# 29524  Visakhapatnam  2020-06-25  13.45   58.54  2.30  21.60  13.09  12.27
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00   66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %% [markdown]
# # For information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %% [markdown]
# # It gives detail statistic of dataset

# %%
df.describe()
# Out:
#               PM2.5          PM10            NO           NO2           NOx  \
# count  24933.000000  18391.000000  25949.000000  25946.000000  25346.000000
# mean      67.450578    118.127103     17.574730     28.560659     32.309123
# std       64.661449     90.605110     22.785846     24.474746     31.646011
# min        0.040000      0.010000      0.020000      0.010000      0.000000
# 25%       28.820000     56.255000      5.630000     11.750000     12.820000
# 50%       48.570000     95.680000      9.890000     21.690000     23.520000
# 75%       80.590000    149.745000     19.950000     37.620000     40.127500
# max      949.990000   1000.000000    390.680000    362.210000    467.630000
#
#                 NH3            CO           SO2            O3       Benzene  \
# count  19203.000000  27472.000000  25677.000000  25509.000000  23908.000000
# mean      23.483476      2.248598     14.531977     34.491430      3.280840
# ...

# %% [markdown]
# # To count value

# %%
df.value_counts()
# Out:
# City           Date        PM2.5  PM10    NO     NO2    NOx    NH3    CO    SO2    O3      Benzene  Toluene  Xylene  AQI    AQI_Bucket
# Amaravati      2017-11-25  81.40  124.50  1.44   20.50  12.08  10.72  0.12  15.24  127.09  0.20     6.50     0.06    184.0  Moderate        1
# Hyderabad      2019-06-20  18.96  56.20   1.96   11.05  7.20   10.23  0.32  6.32   27.66   0.31     1.45     0.13    54.0   Satisfactory    1
#                2019-07-12  18.41  39.59   3.63   15.07  10.10  13.38  0.42  8.40   16.69   0.26     2.87     0.09    45.0   Good            1
#                2019-07-11  16.54  39.46   2.57   12.01  7.99   8.42   0.35  5.19   16.63   0.17     0.79     0.04    40.0   Good            1
#                2019-07-10  12.67  31.67   2.39   9.99   6.38   4.88   0.33  4.32   16.24   0.08     0.23     0.01    36.0   Good            1
# ...

# %%
#It shows the number of rows and columns in the dataset
df.shape
# Out:
# (29531, 16)

# %% [markdown]
# # Checking and counting for missing data points from each columns

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %% [markdown]
# # To remove the missing values

# %%
DataCleaned=df.dropna()
DataCleaned.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %% [markdown]
# # datatype for each attribute

# %%
df.dtypes
# Out:
# City           object
# Date           object
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket     object
# dtype: object

# %%
#Minimum 
df.min()
# Out:
# City        Ahmedabad
# Date       2015-01-01
# PM2.5            0.04
# PM10             0.01
# NO               0.02
# NO2              0.01
# NOx               0.0
# NH3              0.01
# CO                0.0
# SO2              0.01
# O3               0.01
# Benzene           0.0
# Toluene           0.0
# Xylene            0.0
# AQI              13.0
# dtype: object

# %%
#Maximum
df.max()
# Out:
# City       Visakhapatnam
# Date          2020-07-01
# PM2.5             949.99
# PM10              1000.0
# NO                390.68
# NO2               362.21
# NOx               467.63
# NH3               352.89
# CO                175.81
# SO2               193.86
# O3                257.73
# Benzene           455.03
# Toluene           454.85
# Xylene            170.37
# AQI               2049.0
# dtype: object

# %% [markdown]
# # To find Unique Values

# %%
df.AQI_Bucket.unique()
# Out:
# array([nan, 'Poor', 'Very Poor', 'Severe', 'Moderate', 'Satisfactory',
#        'Good'], dtype=object)

# %% [markdown]
# Air Quality Index (AQI) is a numerical scale used to measure and report air quality of an area on a given day.

# %%
# Data Availability
print(f"The available data is between {df['Date'].min()} and {df['Date'].max()}")
# Out:
# The available data is between 2015-01-01 and 2020-07-01

# %% [markdown]
# # Combining the Benzene, Toluene and Xylene levels into one column - BTX

# %%
# Combining the Benzene, Toluene and Xylene levels into one column - BTX
df['BTX'] = df['Benzene'] + df['Toluene'] + df['Xylene']
df.drop(['Benzene','Toluene','Xylene'],axis=1);

# %% [markdown]
# # Combining the PM2.5 and PM10 into one column - Particulate Matter

# %%
df['Particulate_Matter'] = df['PM2.5'] + df['PM10']

# %%
100*(df['PM2.5'].isnull().sum()/df.shape[0]) #the data points have PM2.5 values missing in whole dataset.
# Out:
# 15.570078900138837

# %% [markdown]
# # To get first and last five numeric data

# %%
num=df._get_numeric_data()
num[num<0]=0
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %% [markdown]
# # To count total number of cities in dataset

# %%
cities = df['City'].value_counts()
print(f'Total number of cities in the dataset : {len(cities)}')
print(cities.index)
# Out:
# Total number of cities in the dataset : 26
# Index(['Ahmedabad', 'Delhi', 'Mumbai', 'Bengaluru', 'Lucknow', 'Chennai',
#        'Hyderabad', 'Patna', 'Gurugram', 'Visakhapatnam', 'Amritsar',
#        'Jorapokhar', 'Jaipur', 'Thiruvananthapuram', 'Amaravati',
#        'Brajrajnagar', 'Talcher', 'Kolkata', 'Guwahati', 'Coimbatore',
#        'Shillong', 'Chandigarh', 'Bhopal', 'Ernakulam', 'Kochi', 'Aizawl'],
#       dtype='object')

# %% [markdown]
# # Let's create a new dataframe called pollutants containg the major pollutants responsible for air pollution

# %%
Pollutants = ['PM2.5','PM10','NO2', 'CO', 'SO2','O3', 'BTX']

# %% [markdown]
# Pollutants namely 'PM2.5','PM10','NO2', 'CO', 'SO2','O3'and 'BTX' are the major parameters taken into consideration while deriving AQI of a region.

# %% [markdown]
# # Data Type

# %%
#To count AQI 
df['AQI_Bucket'].value_counts(ascending= True)
# Out:
# Severe          1338
# Good            1341
# Very Poor       2337
# Poor            2781
# Satisfactory    8224
# Moderate        8829
# Name: AQI_Bucket, dtype: int64

# %% [markdown]
# # Catplot for AQI Bucket

# %%
sns.catplot(x = "AQI_Bucket", kind= "count", palette = "ch: 2.87", height=5, aspect=1.1, data = df)

# %% [markdown]
# There are six categories of AQI which are Poor, Very Poor,Severe, Moderate, Satisfactory and Good

# %% [markdown]
# # The subplot of PM2.5 for all Cities

# %%
df[['PM2.5', 'City']].groupby(['City']).median().sort_values("PM2.5", ascending = False).plot.bar()
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# Delhi has the highest levels of PM2.5 Major reasons behind the rise of PM2.5 levels in Delhi are increasing traffic, dust and smoke from fires.

# %% [markdown]
# # The subplot of PM10 for all cities

# %%
df[['PM10', 'City']].groupby(['City']).median().sort_values("PM10", ascending = False).plot.bar()
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Data of NO for all cities

# %%
df[['NO', 'City']].groupby(['City']).median().sort_values("NO", ascending = False).plot.bar(color='green')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Data of (Nitrogen Oxides) NO2 for all cities

# %%
df[['NO2', 'City']].groupby(['City']).median().sort_values("NO2", ascending = False).plot.bar(color='blue')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Data of (Carbon Mono-oxide) CO for all cities

# %%
df[['CO', 'City']].groupby(['City']).median().sort_values("CO", ascending = False).plot.bar(color='yellow')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Data of (Sulphur Dioxide) SO2 for all cities

# %%
df[['SO2', 'City']].groupby(['City']).median().sort_values("SO2", ascending = False).plot.bar(color='Red')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Data of (Ozone) O3 for all cities

# %%
df[['O3', 'City']].groupby(['City']).median().sort_values("O3", ascending = False).plot.bar(color='Purple')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# # Data of BTX for all cities

# %%
df[['BTX', 'City']].groupby(['City']).median().sort_values("BTX", ascending = False).plot.bar(color='Orange')
# Out:
# <AxesSubplot:xlabel='City'>

# %% [markdown]
# Kolkata and Ahmedabad has the highest stake when nitrogen dioxides, sulphur dioxides and carbon monoxide is concerned, whereas Gurugram and Kolkata are the most polluted due to ozone and benzene respectively. On a broader view, Ernakulam and Amaravati seem to be less hazardous compared to other mid-tier and top-tier cities.

# %% [markdown]
# # Bar Graph - Pollution w.r.t Cities

# %%
plt.figure(figsize=(12,15))
df.groupby('PM2.5')['City'].value_counts().nlargest(25).plot(kind='barh')
plt.title('Pollution with respect to cities')
plt.xlabel('City')
plt.ylabel('Pollutants')
plt.show()

# %% [markdown]
# # #The SO2 and NO2 comparison

# %%
df1000 = df[:] [:1000]
sns.lmplot(x = "SO2", y ="NO2",data = df1000, order = 2, ci = None)

# %% [markdown]
# # Displot of Polluted Cities

# %%
plt.figure(figsize=(20,25))
sns.displot(df['City'])
plt.grid = (True)

# %% [markdown]
# # Scatter Plot of all columns

# %%
#It shows pair plot of main elements of pollution
sns.set()
cols = ['SO2', 'NOx', 'O3', 'NO2', 'PM2.5']
sns.pairplot(df[cols], height = 2.5)
plt.show()

# %% [markdown]
# Here above SO2 and NO2 are correlated but others are not correlated

# %% [markdown]
# # To find correlation with other variables

# %%
#To find correlation with other variables
corr=df.corr()
corr
# Out:
#                        PM2.5      PM10        NO       NO2       NOx  \
# PM2.5               1.000000  0.846498  0.433491  0.350709  0.436792
# PM10                0.846498  1.000000  0.502349  0.464380  0.527768
# NO                  0.433491  0.502349  1.000000  0.478070  0.794890
# NO2                 0.350709  0.464380  0.478070  1.000000  0.627627
# NOx                 0.436792  0.527768  0.794890  0.627627  1.000000
# NH3                 0.275086  0.376816  0.185621  0.234938  0.166224
# CO                  0.089912  0.112588  0.212607  0.356521  0.226992
# SO2                 0.132325  0.256974  0.170322  0.392233  0.238397
# O3                  0.161238  0.244919  0.014580  0.293349  0.093170
# Benzene             0.023911  0.022265  0.035771  0.025260  0.039121
# Toluene             0.117080  0.169335  0.150857  0.273926  0.189386
# Xylene              0.114579  0.081700  0.094237  0.171701  0.087398
# AQI                 0.659181  0.803313  0.452191  0.537071  0.486450
# ...

# %% [markdown]
# # Heatmap

# %%
#To plot heatmap
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# PM2.5 has a correlation with PM10. There is some correlation between carbon monoxide and sulphur dioxide.Sulphur dioxide and nitrogen dioxide is also correlated. But others are not related directly with each other.

# %% [markdown]
# # Bar Graph - Pollution with respect to cities

# %%
plt.figure(figsize=(10,10))
df.groupby('PM2.5')['City'].value_counts().nlargest(25).plot(kind='barh')
plt.title('Pollution with respect to cities')
plt.xlabel('City')
plt.ylabel('Pollutants')
plt.show()

# %%
plt.figure(figsize=(25,12))
sns.countplot(df['City'])
plt.grid = (True)

# %% [markdown]
# # Conclusion

# %% [markdown]
# From above analysis and research carried out from the air pollution dataset it is observed that the pollutant levels of some harmful particulate matters such as PM10 are high in the air. PM10 are minute particles present in the air and exposure to it is very harmful for health.Road dust and construction dust are major PM10 contributors.When the level of these particles increases and penetrate deeply in to the lungs, you can experience number of health impacts like breathing problem, burning or sensation in the eyes.

# %% [markdown]
# # Result

# %% [markdown]
# By analyzing the daily AQI data for different cities of India it was found that Ahmedabad, Chennai, Delhi, Bengaluru, Mumbai, Hyderabad and Lucknow have the highest AQI values on an average daily basis for the year 2015- 2020. As 'PM10' is the main pollutant resulting in pollution. Delhi have the highest counting of PM10 which indicates that Delhi is most polluted city. Even people with no prior respiratory problems are also vulnerable to respiratory disorders due to pollution.For the past few decades, the world has been bustling with various human activities which has contributed to air pollution. But there is some drop in pollution level from 2020 due to Covid19 crisis.
